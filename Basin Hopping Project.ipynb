# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)

def total_energy(positions):
    
    E = 0
    N_atom = int(len(positions)/3)
    
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

def neighbor(pos_now, kT):
    N = len(pos_now)
    return pos_now + kT*np.random.random_sample((N,))

def acceptance_probability(dE, kT):
    if dE<0:
        return 1
    else:
        return np.exp(-dE/kT)

# %%
N_atom = 11
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=50, T=2.3, stepsize=3.5, disp=True)
# Out:
# basinhopping step 0: f -28.5482
# ...
# basinhopping step 1: f -29.6841 trial_f -29.6841 accepted 1  lowest_f -29.6841
# found new global minimum on step 1 with function value -29.6841
# ...
# basinhopping step 2: f -30.8219 trial_f -30.8219 accepted 1  lowest_f -30.8219
# found new global minimum on step 2 with function value -30.8219
# basinhopping step 3: f -30.8219 trial_f -26.4905 accepted 0  lowest_f -30.8219
# ...
# basinhopping step 4: f -30.8219 trial_f -29.8617 accepted 0  lowest_f -30.8219
# ...
# basinhopping step 5: f -31.4269 trial_f -31.4269 accepted 1  lowest_f -31.4269
# found new global minimum on step 5 with function value -31.4269
# basinhopping step 6: f -29.7585 trial_f -29.7585 accepted 1  lowest_f -31.4269
# ...
# basinhopping step 7: f -29.7631 trial_f -29.7631 accepted 1  lowest_f -31.4269
# basinhopping step 8: f -29.8222 trial_f -29.8222 accepted 1  lowest_f -31.4269
# ...
# basinhopping step 9: f -30.0318 trial_f -30.0318 accepted 1  lowest_f -31.4269
# ...

# %%
import matplotlib.pyplot as plt

plt.plot([-28.5482,
-29.6841,
-30.8219,
-30.8219,
-30.8219,
-31.4269,
-29.7585,
-29.7631,
-29.8222,
-30.0318,
-29.738,
-31.6147,
-31.0005,
-30.9143,
-31.7956,
-30.9512,
-31.7956,
-31.7956,
-30.6838,
-30.6838,
-30.6357,
-30.6357,
-30.6357,
-30.6357,
-31.7737,
-31.7737,
-30.9539,
-30.8386,
-30.922,
-29.7857,
-30.8564,
-31.1517,
-31.7737,
-30.7829,
-30.1763,
-29.7821,
-29.7911,
-30.9202,
-30.8564,
-31.7956,
-31.7956,
-31.7956,
-29.7911,
-30.8386,
-30.8386,
-30.5066,
-28.8233,
-31.8892,
-31.8892,
-29.6841,
-31.7737,
 ])
plt.xlabel('Step')
plt.ylabel('Energy')
plt.title('BH Energy for N=11 using T=2.3, S=3.5')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)

def total_energy(positions):
    
    E = 0
    N_atom = int(len(positions)/3)
    
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

def neighbor(pos_now, kT):
    N = len(pos_now)
    return pos_now + kT*np.random.random_sample((N,))

def acceptance_probability(dE, kT):
    if dE<0:
        return 1
    else:
        return np.exp(-dE/kT)

# %%
N_atom = 15
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=50, T=2.5, stepsize=3.3, disp=True)
# Out:
# ...
# basinhopping step 0: f -42.2245
# ...
# basinhopping step 1: f -48.5148 trial_f -48.5148 accepted 1  lowest_f -48.5148
# found new global minimum on step 1 with function value -48.5148
# ...
# basinhopping step 2: f -47.6693 trial_f -47.6693 accepted 1  lowest_f -48.5148
# ...
# basinhopping step 3: f -47.6523 trial_f -47.6523 accepted 1  lowest_f -48.5148
# ...
# basinhopping step 4: f -49.4908 trial_f -49.4908 accepted 1  lowest_f -49.4908
# found new global minimum on step 4 with function value -49.4908
# ...
# basinhopping step 5: f -52.3226 trial_f -52.3226 accepted 1  lowest_f -52.3226
# found new global minimum on step 5 with function value -52.3226
# ...
# basinhopping step 6: f -52.3226 trial_f -47.4035 accepted 0  lowest_f -52.3226
# ...
# basinhopping step 7: f -52.3226 trial_f -46.3608 accepted 0  lowest_f -52.3226
# ...
# basinhopping step 8: f -50.4149 trial_f -50.4149 accepted 1  lowest_f -52.3226
# ...
# basinhopping step 9: f -50.4149 trial_f -46.5043 accepted 0  lowest_f -52.3226
# ...

# %%
import matplotlib.pyplot as plt

plt.plot([-42.2245,
-48.5148,
-47.6693,
-47.6523,
-49.4908,
-52.3226,
-52.3226,
-52.3226,
-50.4149,
-50.4149,
-50.4149,
-50.4149,
-48.2355,
-48.2355,
-48.4811,
-49.6232,
-48.5981,
-52.3226,
-52.3226,
-52.3226,
-52.3226,
-52.3226,
-52.3226,
-51.3726,
-50.4149,
-50.4149,
-47.115,
-47.58,
-49.3175,
-49.3175,
-49.3175,
-50.3123,
-47.1303,
-47.1303,
-50.2677,
-50.2677,
-51.3726,
-49.2651,
-49.2651,
-47.4306,
-47.4306,
-47.2752,
-47.2066,
-47.2066,
-47.5687,
-47.4207,
-47.4207,
-51.418,
-51.418,
-51.418,
-47.7249,
 ])
plt.xlabel('Step')
plt.ylabel('Energy')
plt.title('BH Energy for N=15 using T=2.5, S=3.3')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import basinhopping

def LJ(r):
    r6 = r**6
    r12 = r6*r6
    return 4*(1/r12 - 1/r6)

def total_energy(positions):
    
    E = 0
    N_atom = int(len(positions)/3)
    
    for i in range(N_atom-1):
        for j in range(i+1, N_atom):
            pos1 = positions[i*3:(i+1)*3]
            pos2 = positions[j*3:(j+1)*3]
            dist = np.linalg.norm(pos1-pos2)
            E += LJ(dist)
    return E
            
def init_pos(N, L=5):
    return L*np.random.random_sample((N*3,))

def neighbor(pos_now, kT):
    N = len(pos_now)
    return pos_now + kT*np.random.random_sample((N,))

def acceptance_probability(dE, kT):
    if dE<0:
        return 1
    else:
        return np.exp(-dE/kT)

# %%
N_atom = 19
pos = init_pos(N_atom)
res = basinhopping(total_energy, pos, niter=50, T=3.2, stepsize=2.5, disp=True)
# Out:
# ...
# basinhopping step 0: f -66.9192
# ...
# basinhopping step 1: f -66.9192 trial_f -60.5835 accepted 0  lowest_f -66.9192
# ...
# basinhopping step 2: f -66.9677 trial_f -66.9677 accepted 1  lowest_f -66.9677
# found new global minimum on step 2 with function value -66.9677
# ...
# basinhopping step 3: f -68.418 trial_f -68.418 accepted 1  lowest_f -68.418
# found new global minimum on step 3 with function value -68.418
# ...
# basinhopping step 4: f -68.418 trial_f -66.3953 accepted 0  lowest_f -68.418
# ...
# basinhopping step 5: f -72.6598 trial_f -72.6598 accepted 1  lowest_f -72.6598
# found new global minimum on step 5 with function value -72.6598
# ...
# basinhopping step 6: f -72.6598 trial_f -62.6372 accepted 0  lowest_f -72.6598
# ...
# basinhopping step 7: f -72.6598 trial_f -67.6131 accepted 0  lowest_f -72.6598
# ...
# basinhopping step 8: f -68.3933 trial_f -68.3933 accepted 1  lowest_f -72.6598
# ...
# basinhopping step 9: f -68.3933 trial_f -57.4688 accepted 0  lowest_f -72.6598
# ...

# %%
import matplotlib.pyplot as plt

plt.plot([-66.9192,
-66.9192,
-66.9677,
-68.418,
-68.418,
-72.6598,
-72.6598,
-72.6598,
-68.3933,
-68.3933,
-69.29,
-69.3623,
-69.3623,
-69.3623,
-69.3623,
-68.6321,
-64.9561,
-69.9235,
-69.9235,
-69.9235,
-69.9235,
-58.5839,
-58.5748,
-58.849,
-58.849,
-58.849,
-58.849,
-58.849,
-57.5107,
-60.3448,
-58.0823,
-58.0823,
-57.5107,
-56.4409,
-60.3674,
-60.3674,
-60.3674,
-60.3674,
-60.3674,
-57.4203,
-60.0672,
-60.0672,
-60.0672,
-60.0672,
-60.0672,
-59.2088,
-52.7883,
-56.5736,
-58.2939,
-58.2939,
-54.2642,
 ])
plt.xlabel('Step')
plt.ylabel('Energy')
plt.title('BH Energy for N=19 using T=3.2, S=2.5')
plt.show()
