# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np


f = lambda x,a,b,c: a*x*np.sin(b)+c  


x_min, x_max = 0, 7
npoints = 95
a,b,c = 4.2, 3.3, 2.7

x = np.linspace(x_min, x_max, npoints)
y = f(x,a,b,c) + np.random.rand(npoints) - 0.55


params, extras = curve_fit(f, x, y)

plt.plot(x,f(x,a,b,c), '--', label='ideal function')
plt.plot(x,y, 'o', label='noisy data')
plt.plot(x,f(x,params[0],params[1],params[2]), label='curve_fit')

plt.xlabel('x')
plt.ylabel('$f(x)$')
plt.xlim([x_min, x_max])
plt.legend()
plt.show()

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np


f = lambda x,a,b,c: a*np.cos(b*x)+c  


x_min, x_max = 0, 15
npoints = 90
a,b,c = 3.7, 2.3, 1.2

x = np.linspace(x_min, x_max, npoints)
y = f(x,a,b,c) + np.random.rand(npoints) - 0.5


params, extras = curve_fit(f, x, y)

plt.plot(x,f(x,a,b,c), '--', label='ideal function')
plt.plot(x,y, 'o', label='noisy data')
plt.plot(x,f(x,params[0],params[1],params[2]), label='curve_fit')

plt.xlabel('x')
plt.ylabel('$f(x)$')
plt.xlim([x_min, x_max])
plt.legend()
plt.show()

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np


f = lambda x,a,b,c: a*x*np.sin(b*x)+c  


x_min, x_max = 0, 15
npoints = 85
a,b,c = 2.7, 1.5, 1.2

x = np.linspace(x_min, x_max, npoints)
y = f(x,a,b,c) + np.random.rand(npoints) - 0.5


params, extras = curve_fit(f, x, y)

plt.plot(x,f(x,a,b,c), '--', label='ideal function')
plt.plot(x,y, 'o', label='noisy data')
plt.plot(x,f(x,params[0],params[1],params[2]), label='curve_fit')

plt.xlabel('x')
plt.ylabel('$f(x)$')
plt.xlim([x_min, x_max])
plt.legend()
plt.show()

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np


f = lambda x,a,b,c: a*np.arctan(b*x)+c


x_min, x_max = 0, 10
npoints = 50
a,b,c = 1.7, 1.5, 1.2

x = np.linspace(x_min, x_max, npoints)
y = f(x,a,b,c) + np.random.rand(npoints) - 0.52


params, extras = curve_fit(f, x, y)

plt.plot(x,f(x,a,b,c), '--', label='ideal function')
plt.plot(x,y, 'o', label='noisy data')
plt.plot(x,f(x,params[0],params[1],params[2]), label='curve_fit')

plt.xlabel('x')
plt.ylabel('$f(x)$')
plt.xlim([x_min, x_max])
plt.legend()
plt.show()

# %%
#from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy as np


f = lambda x: x*np.sin(x)     #fit function


x_min, x_max = 1, 12           #define parameters for plot
npoints = 12

x = np.linspace(x_min, x_max, npoints)
y = np.array([35, 29, 80, 155, 276, 243, 134, 83, 74, 61, 58, 24])
fit = np.polyfit(x,y,3)
y_p = np.polyval(fit,x)

#params, extras = curve_fit(f, x, y)

plt.plot(x,f(x), '--', label='ideal function')
plt.plot(x,y, 'o', label='tornadoes')
plt.plot(x,y_p, label='polyfit')

plt.xlabel('Month')
plt.ylabel('Number of Tornadoes')
plt.xlim([x_min, x_max])
plt.ylim([0, 280])
plt.legend()
plt.show()
